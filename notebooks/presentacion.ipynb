# %% [markdown]
# ## Análisis de datos
#
# ### Información general de la base
#
# Se cuenta con 26,975 observaciones y 16 variables.
#
# Información general de cada variable:
#
# ##### 1. ID_USER
#
# Hay 4,000 usuarios.
#
#
# #### (Numéricas)
#
#
# ##### 2. monto
#
# Monto de la transacción (float).  Rango de 0.01 a 999.91 con una distribución uniforme.
#
# ##### 3. linea_tc
#
# Línea de la tarjeta de crédito (int). Tiene 75 cantidades únicas de línea de crédito. El rango va de 25,000 a 99,000.
#
# ##### 4. interes_tc
#
# Interés de la tarjeta de crédito (int). Tiene 33 cantidades unicas de línea de crédito. El rango va de 32 a 64.
#
# ##### 5. dcto
#
# Descuento de la compra (float).  Por lo menos el 50% de las transacciones tienen un descuento de cero, lo que resta tiene un mínimo de 18 y un máximo de 199.
#
#
# ##### 6. cashback
#
# Dinero que se devuelve (float). Tiene un rango de 0 a 19.99.
#
# #### (Categóricas)
#
# ##### 7. genero
#
# 1. M (50%)
# 2. F (39%)
#
# ##### 8. dispositivo
#
# Dispositivos con características diferentes; sus proporciones van entre 4.78% y 5.23%.
#
# ##### 9. establecimiento
#
# 1. Restaurante (12.8%)
# 2. Abarrotes (12.66%)
# 3. Super (12.39%)
# 4. MPago (12.39%)
# 5. Farmacia (12.02)
#
# ##### 10. ciudad
#
# 1. Toluca (14.82%)
# 2. Guadalajara (14.21%)
# 3. Mérida (13.94%)
# 4. Monterrey (13.74%).
#
#
# ##### 11. tipo_tc
#
# 1. Física (70.08%)
# 2. Virtual (29.92%)
#
# ##### 12. status_txn
#
# 1. Aceptada (69.86%)
# 2. En proceso (19.80%)
# 3. Rechazada (10.34%)
#
# ##### 13. is_prime
#
# 1. False (86.81%)
# 2. True (13.19%)
#
# ##### 14. fraude
#
# 1. False (97%)
# 2. True (3%)
#
# #### (Temporales)
#
# ##### 15. fecha
#
# ##### 16. hora

# %% [markdown]
# pendientes:
#
# - imputar genero bien.
#
# - status_txn graficos
#
# - saber bien lo de la línea de crédito y el interes
#
# - saber distribución de dcto y cashback
#
# - Ve si puedes hacer alguna categorización
